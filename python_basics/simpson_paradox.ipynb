# %% [markdown]
# Capital approval rates have gone down for our overall approval rate. Let’s say last week it was 85% and the approval rate went down to 82% this week which is a statistically significant reduction.
#
# The first analysis shows that all approval rates stayed flat or increased over time when looking at the individual products:
#
# Product 1: 84% to 85% week over week
# Product 2: 77% to 77% week over week
# Product 3: 81% to 82% week over week
# Product 4: 88% to 88% week over week
# What could be the cause of the decrease?

# %% [markdown]
# Even though the approval rates for each individual product stayed the same or increased, the overall approval rate decreased. That means the composition of the total approvals has changed.

# %% [markdown]
# The mix of applications across products changed between last week and this week.
#
# In particular:
# 	•	Products with lower approval rates (e.g., Product 2 at 77%) likely made up a larger share of total applications this week.
# 	•	Products with higher approval rates (e.g., Product 4 at 88%) likely had fewer applications this week.
#
# So, even though product-level approval rates didn’t drop, shifting more volume into lower-performing products pulled the overall rate down.
